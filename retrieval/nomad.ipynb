# %%
import requests
import json
import pandas as pd
from time import sleep

def check_nested_keys(d, keys):
    for key in keys:
        if key not in d:
            return False
        d = d[key]
    return True

url = 'http://nomad-lab.eu/prod/v1/api/v1/entries/archive/query'

excluded_elements = [
    "He", "Ne", "Ar", "Kr", "Xe", "Rn", "U", "Th", "Rn", "Tc", "Po", "Pu", "Pa",
    ]

query = {
    # "owner": "visible",
    # 'not':{
    #     'results.material.elements': {
    #         'any': excluded_elements
    #     }
    # }
    "results.method.simulation.program_name:any": [
        "VASP"
    ],
    "quantities:all": [
        "results.properties.structures",
        "results.properties.structures.structure_original",
        "results.properties.structures.structure_conventional",
        "results.properties.structures.structure_primitive"
    ]
}

required = {
    "results": {
        "material": {
            "chemical_formula_reduced": "*"
        },
        "properties": {
            "structures": "*"
        }
    
    }
}

df = pd.DataFrame(columns=['entry_id', 'chemical_formula', 'structure_original', 'structure_primitive', 'structure_conventional', 'json'])

page_after_value = None
cnt = 0
save_cnt = 0
total = 0
while True:
    # try the post, if it fails, try again
    try:
        response = requests.post(
            url, json = dict(
                query=query,
                required=required,
                pagination=dict(page_size=100, page_after_value=page_after_value)
            )
        )
        data = response.json()
    except Exception as e:
        print(f"Error: {e}")
        sleep(30)
        continue

    if len(data['data']) == 0:
        break

    page_after_value = data['pagination']['next_page_after_value']

    for entry in data['data']:
        # check if all required keys are present
        if not check_nested_keys(entry, ['archive', 'results', 'properties', 'structures']):
            continue

        # save to dataframe
        entry_id = entry['entry_id']
        chemical_formula = entry['archive']['results']['material']['chemical_formula_reduced']
        structure_original = entry['archive']['results']['properties']['structures']['structure_original']
        structure_primitive = entry['archive']['results']['properties']['structures']['structure_primitive']
        structure_conventional = entry['archive']['results']['properties']['structures']['structure_conventional']
        entry_json = json.dumps(entry)

        # using pd.concat
        df = pd.concat([df, pd.DataFrame([[entry_id, chemical_formula, structure_original, structure_primitive, structure_conventional, entry_json]], columns=['entry_id', 'chemical_formula', 'structure_original', 'structure_primitive', 'structure_conventional', 'json'])], ignore_index=True)
        
        cnt += 1
        save_cnt += 1
    
    total += len(data['data'])
    print(f"Processed {cnt}/{total} entries")

    # save to csv every 100000 entries
    if save_cnt > 100000:
        df.to_csv(f'data/{page_after_value}.csv', index=False)
        print("Saved to csv")
        save_cnt = 0

    break
# Out:
# Processed 34/100 entries

# %%
df
# Out:
#                         entry_id chemical_formula  \
# 0   ----9KNOtIZc9bDFEWxgjeSRsJrC          CaFe2Re
# 1   ---K_oamb0brcfuzk7XeBGT1l6pp          Ag2LaNi
# 2   ---NRSI3eJ3cEV97kfl9eKZ38L5M           NaNi2V
# 3   ---OWGSfJGTXSTY71gcX0l_HFO9A          LiSr2Zr
# 4   ---SR2t2-lkZvBWVaF-eCLkf7BQh            OsSbY
# 5   ---mWpSogZteOYvPrpyT6PUZfSQJ          MnNaPm2
# 6   ---n93Np1-HZAuVg04MKVYobIt2m     As2F12I2Se12
# 7   ---nb1Zrg9nx-S-SZgvXiB959vtd          Ir2ReSi
# 8   ---vOlFiwCCU4JeZ0QjGTKQZYbXS          AgNiZr2
# 9   ---x0dhqdpEkEjP-AT6KK_5q_E8D           ErNaO3
# 10  --0GKq8ho6MlOHaG7o_rD-S-U-E6          Br2IrOs
# 11  --0Hj5fqGLafCh90yCg1gBBRRlKo            Be3Os
# 12  --0IDLLJdpos7FrdyNXJnVmfwDB7        B12Cs4O20
# 13  --0R5E4q1f7f2N9lkWZ3YOzOSYIs          AgClSe2
# 14  --0RSTtl4mvX3Nd0JjhL_V1YV1ip          Mn2PbTi
# 15  --0SDuSOM_gpweM3PDb0WOFgYDyv         HfNbTcTi
# 16  --0j5ZSyaMCvDDPENJdx-bnk-ifl           CuFeK2
# 17  --0sGA2VG1ZYL-LltKv3PXliKL2U           NbPt2Y
# 18  --0st8idlqcwj6lC1fXJpB0whgF6          CoSi2Tc
# 19  --0zJSUL9VfKgVKnjptPOuOMR-L9          BrPd2Te
# 20  --1-7LX98ImyKtzqNUzXvRv8d90y          DyRu2Te
# 21  --1ACsykzxGdpbGFAT1VLUbScCaU          NaOs2Sb
# 22  --1DNnK8aUgaCsmYGpUBTAkLv8YI           Fe2SmW
# 23  --1FLWSRxIYsEAMsfDrAv3dp98Xb           InIrW2
# 24  --1MQjqSE6JRlv1CNCVHfs98jtFq          Br3CuS4
# 25  --1Qs6hNl930zVtZyy9B8ssMZmCZ          CoNa2Re
# 26  --1e8JrytFETTbsEGVjC1p4OJZE5          BiGeSi2
# 27  --1gwlbbaF1-w4jvD3Af0C2XDpQ8             B6Yb
# 28  --1u_M0iAbGcRwSwxCGTokME3NwE          ErLaSr2
# 29  --27T8oNs8FzfULXyE0lz02svztK          PtScZn2
# 30  --2ArsWJdSht5KR5aO8ohzS6aobE          BiCdInK
# 31  --2HMe6zK88SpSB_vu7PTjo87kxi   C26Cl4H28N4Pb2
# 32  --2HVB0266-EoBj8l5hxwM0dLcB-          Au2MgTl
# 33  --2NBi8NIDQyGkmhX2mwTIdOJ_89          MoNb2Sc
#
#                                    structure_original  \
# 0   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 1   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 2   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 3   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 4   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 5   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 6   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 7   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 8   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 9   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 10  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 11  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 12  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 13  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 14  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 15  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 16  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 17  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 18  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 19  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 20  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 21  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 22  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 23  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 24  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 25  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 26  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 27  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 28  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 29  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 30  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 31  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 32  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 33  {'dimension_types': [1, 1, 1], 'lattice_vector...
#
#                                   structure_primitive  \
# 0   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 1   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 2   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 3   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 4   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 5   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 6   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 7   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 8   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 9   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 10  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 11  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 12  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 13  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 14  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 15  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 16  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 17  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 18  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 19  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 20  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 21  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 22  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 23  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 24  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 25  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 26  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 27  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 28  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 29  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 30  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 31  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 32  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 33  {'dimension_types': [1, 1, 1], 'lattice_vector...
#
#                                structure_conventional  \
# 0   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 1   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 2   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 3   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 4   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 5   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 6   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 7   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 8   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 9   {'dimension_types': [1, 1, 1], 'lattice_vector...
# 10  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 11  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 12  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 13  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 14  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 15  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 16  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 17  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 18  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 19  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 20  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 21  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 22  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 23  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 24  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 25  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 26  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 27  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 28  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 29  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 30  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 31  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 32  {'dimension_types': [1, 1, 1], 'lattice_vector...
# 33  {'dimension_types': [1, 1, 1], 'lattice_vector...
#
#                                                  json
# 0   {"entry_id": "----9KNOtIZc9bDFEWxgjeSRsJrC", "...
# 1   {"entry_id": "---K_oamb0brcfuzk7XeBGT1l6pp", "...
# 2   {"entry_id": "---NRSI3eJ3cEV97kfl9eKZ38L5M", "...
# 3   {"entry_id": "---OWGSfJGTXSTY71gcX0l_HFO9A", "...
# 4   {"entry_id": "---SR2t2-lkZvBWVaF-eCLkf7BQh", "...
# 5   {"entry_id": "---mWpSogZteOYvPrpyT6PUZfSQJ", "...
# 6   {"entry_id": "---n93Np1-HZAuVg04MKVYobIt2m", "...
# 7   {"entry_id": "---nb1Zrg9nx-S-SZgvXiB959vtd", "...
# 8   {"entry_id": "---vOlFiwCCU4JeZ0QjGTKQZYbXS", "...
# 9   {"entry_id": "---x0dhqdpEkEjP-AT6KK_5q_E8D", "...
# 10  {"entry_id": "--0GKq8ho6MlOHaG7o_rD-S-U-E6", "...
# 11  {"entry_id": "--0Hj5fqGLafCh90yCg1gBBRRlKo", "...
# 12  {"entry_id": "--0IDLLJdpos7FrdyNXJnVmfwDB7", "...
# 13  {"entry_id": "--0R5E4q1f7f2N9lkWZ3YOzOSYIs", "...
# 14  {"entry_id": "--0RSTtl4mvX3Nd0JjhL_V1YV1ip", "...
# 15  {"entry_id": "--0SDuSOM_gpweM3PDb0WOFgYDyv", "...
# 16  {"entry_id": "--0j5ZSyaMCvDDPENJdx-bnk-ifl", "...
# 17  {"entry_id": "--0sGA2VG1ZYL-LltKv3PXliKL2U", "...
# 18  {"entry_id": "--0st8idlqcwj6lC1fXJpB0whgF6", "...
# 19  {"entry_id": "--0zJSUL9VfKgVKnjptPOuOMR-L9", "...
# 20  {"entry_id": "--1-7LX98ImyKtzqNUzXvRv8d90y", "...
# 21  {"entry_id": "--1ACsykzxGdpbGFAT1VLUbScCaU", "...
# 22  {"entry_id": "--1DNnK8aUgaCsmYGpUBTAkLv8YI", "...
# 23  {"entry_id": "--1FLWSRxIYsEAMsfDrAv3dp98Xb", "...
# 24  {"entry_id": "--1MQjqSE6JRlv1CNCVHfs98jtFq", "...
# 25  {"entry_id": "--1Qs6hNl930zVtZyy9B8ssMZmCZ", "...
# 26  {"entry_id": "--1e8JrytFETTbsEGVjC1p4OJZE5", "...
# 27  {"entry_id": "--1gwlbbaF1-w4jvD3Af0C2XDpQ8", "...
# 28  {"entry_id": "--1u_M0iAbGcRwSwxCGTokME3NwE", "...
# 29  {"entry_id": "--27T8oNs8FzfULXyE0lz02svztK", "...
# 30  {"entry_id": "--2ArsWJdSht5KR5aO8ohzS6aobE", "...
# 31  {"entry_id": "--2HMe6zK88SpSB_vu7PTjo87kxi", "...
# 32  {"entry_id": "--2HVB0266-EoBj8l5hxwM0dLcB-", "...
# 33  {"entry_id": "--2NBi8NIDQyGkmhX2mwTIdOJ_89", "...
